# %% [markdown]
# <a href="https://colab.research.google.com/github/enildacoelho/imersaodados/blob/main/imersao05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imersão Alura Dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  

import seaborn as sns
sns.set_theme()

import numpy as np


# Carrega dados (formato  csv, compressão do tipo zip) a partir de uma URL 
url_dados_experimentos = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados_experimentos, compression='zip')

# Inicia uma análise exploratória do conjunto de dados

dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
url_resultados='https://raw.githubusercontent.com/alura-cursos/imersaodados3/main/dados/dados_resultados.csv'

#importa dados resultados a partir de um arquivo csv
dados_resultados=pd.read_csv(url_resultados)
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
# Identifica os valores únicos para tratamento
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
# Identifica quantos tratamentos
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
# Identifica os valores de tempo
dados['tempo'].unique
# Out:
# <bound method Series.unique of 0        24
# 1        72
# 2        48
# 3        48
# 4        72
#          ..
# 23809    24
# 23810    24
# 23811    48
# 23812    24
# 23813    72
# Name: tempo, Length: 23814, dtype: int64>

# %%
dados['tempo'].value_counts()
dados['tempo'].value_counts().plot.bar()

# %%
## Identifica variação de dose
dados['dose'].unique()
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
# Identifica os valores únicos para dose
dados['dose'].unique()
dados['dose'].value_counts()
dados['dose'].value_counts(normalize=True)
dados['dose'].value_counts().plot.bar()

# %%
# Identifica os valores únicos para droga
dados['droga'].nunique()
# Out:
# 3289

# %%
# Identifica os valores únicos para g_0
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# Desafios
#
# ---

# %% [markdown]
# # Desafios Aula 01: Análise de dados, Python, Pandas e novos fármacos

# %%
## Desafio 1: Investigar por que a a classe tratamento é tão desbalanceada? ##
dados['tratamento'].value_counts().plot.bar(figsize=(5,5),title='Tratamentos aplicados')

# %%
## Desafio 2:  Plottar as 5 últimas linhas da tabelas ##

dados.tail(5)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
## Desafio 3: Proporção das classes tratamento ##
dados['tratamento'].value_counts()/dados['tratamento'].count()
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
# Desafio 4: Quantos tipos de drogas analisados ##

df_drogas = dados['droga'].unique()
df_drogas.size

# dados['droga'].nunique()
# Out:
# 3289

# %%
# Desafio 5: Procurar na documentação o método query ##

dados.query('dose=="D1"', inplace = False)
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23804  id_fff506720  com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23807  id_fff7e6992  com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %%
# Desafio 7: Deixar gráficos mais bonitos ##
dados['tratamento'].value_counts().plot.bar(figsize=(5,5),title='Tratamentos aplicados')

# %%
dados['tratamento'].value_counts().plot.bar(figsize=(5,5),title='Tratamentos aplicados')

# %%
## Customizando o Gráfico 

fig, ax= plt.subplots()
cores={'blue', 'yellow'}

x=dados['tratamento'].value_counts()
ax.pie(x, colors=cores, autopct='%.0f%%',explode=(0, 0.1), shadow=True )
ax.set_title('Tratamentos')
# Out:
# Text(0.5, 1.0, 'Tratamentos')

# %%
## Customizando o Gráfico com Matplotlib
fig, ax= plt.subplots()

x=dados['tratamento'].unique()
y=dados['tratamento'].value_counts()
ax.bar(x,y)
ax.set_facecolor('green')

ax.set_title('Tratamentos com_controle e com_droga')
# Out:
# Text(0.5, 1.0, 'Tratamentos com_controle e com_droga')

# %%
## Desafio 7. Um resumo do que aprendeu

# %% [markdown]
# Nesta primeira aula de imersão,  aprenndi a utilizar a bilbioteca pandas e com os métodos, a carregar um arquivo CSV para uma tabela, conhecer a estrutura dos dados, visualizar e nalisar as linhas e valores armazenados.
#
# Para iniciar a análise dos dados, aprendi a selecionar um atributo, identificar os valores únicos, plotar uma visualização dos dados, analisar proporções  e plotar um gráfico para melhor visualização dos dados.
#
# Os dados desse exemplo apresentam resultados de um experimento com celulas submetidas a diferentes compostos, em diferentes dose e com exposição temporal de 24, 48 e 72 horas.

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# # Desafios Aula 2: Estatísticas, visualização de dados e distribuições

# %%
## rename column
dados.rename(columns={'droga':'composto'}, inplace= True)
dados.head(5)
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
## Desafio 1. Ordenar o gráfico countplot
cod_compostos = dados['composto'].value_counts().index[0:5]
cod_compostos
plt.figure(figsize=(8,9))
sns.countplot(x='composto',data=dados.query('composto in @cod_compostos'), order=cod_compostos)

# %%
## Desafio 2. Melhorar a visualização aumentando o tamanho da fonte
ax= sns.countplot(x='composto',data=dados.query('composto in @cod_compostos'), order=cod_compostos)
ax.set_title('Top 5 compostos usados no experimento', fontdict={'fontsize': 15, 'fontweight':'bold'})
ax.set_xlabel('Compostos',fontsize = 12)
ax.set_ylabel('Quantidade',fontsize = 12)
plt.figure(figsize=(8,9))
plt.show();

# %%
## Desafio 3. Plotar os histogramas com Seaborn
sns.histplot(x='g-0', data=dados)

# %%
## Desafio 4. Estudar sobre as estatísticas criadas com o describe()

dados.describe()
dados_statistics=dados.describe()

# %% [markdown]
# **"Mean"**
# **Média**
# A média é uma medida de tendência central que indica o valor onde estão concentrados os dados de um conjunto de valores,
#
#
# **STD()**
# **neDesvio Padrão**
# O desvio padrão também é uma medida de dispersão, que indica quanto os dados estão afastados da média. Um valor de desvio padrão alto indica que os valores estão mais espalhados, mais longe da média, e um desvio padrão baixo indica que os valores estão mais próximos da média. No Pandas fazemos o cálculo através da função std()

# %% [markdown]
# "Mean" Média - A média é uma medida de tendência central que indica o valor onde estão concentrados os dados de um conjunto de valores,
# Moda
# A moda é simples. Nada mais é que o valor que mais se repete dentro de um conjunto. No Pandas, a moda é calculada através da função mode().

# %%
dados['g-0'].describe()
# Out:
# count    23814.000000
# mean         0.248366
# std          1.393399
# min         -5.513000
# 25%         -0.473075
# 50%         -0.008850
# 75%          0.525700
# max         10.000000
# Name: g-0, dtype: float64

# %%
dados['g-0'].mean()
# Out:
# 0.24836629293692816

# %%
dados['composto'].describe()
# Out:
# count         23814
# unique         3289
# top       cacb2b860
# freq           1866
# Name: composto, dtype: object

# %%
## Desafio 5. Refletir sobre a manipulação do tamanho dos gráficos

fig, axes = plt.subplots(2,2,sharey=True, figsize=(10,10))
sns.histplot ( x='g-0', data=dados, ax=axes[0,0])
sns.histplot (x='g-1', data=dados, ax=axes[0,1])
sns.histplot (x='g-2', data=dados, ax=axes[1,1])
sns.histplot (x='g-3', data=dados, ax=axes[1,0])

# %%
fig, axes = plt.subplots(2,2,sharey=True, figsize=(40,10))
sns.histplot ( x='g-0', data=dados, ax=axes[0,0])
sns.histplot (x='g-1', data=dados, ax=axes[0,1])
sns.histplot (x='g-2', data=dados, ax=axes[1,1])
sns.histplot (x='g-3', data=dados, ax=axes[1,0])

# %%
## Desafio 6. Fazer outras análises com o BoxPlot e histograma

fig, axes = plt.subplots(2,2,sharex=True, figsize=(10,10))
sns.histplot ( x='g-0', data=dados, ax=axes[0,0], bins=20)
sns.histplot (x='g-0', data=dados, ax=axes[0,1], bins=40)
sns.histplot (x='g-0', data=dados, ax=axes[1,1], bins=60)
sns.histplot (x='g-0', data=dados, ax=axes[1,0], bins=80)

# %%
sns.boxplot ( x='g-0', data=dados)

# %%
fig, axes = plt.subplots(4,2, sharex=True, figsize=(10,10))
sns.boxplot ( x='g-0', data=dados, ax=axes[0,0])
sns.boxplot (x='g-1', data=dados, ax=axes[0,1])
sns.boxplot (x='g-2', data=dados, ax=axes[1,1])
sns.boxplot (x='g-3', data=dados, ax=axes[1,0])
sns.boxplot ( x='g-4', data=dados, ax=axes[2,0])
sns.boxplot (x='g-5', data=dados, ax=axes[2,1])
sns.boxplot (x='g-6', data=dados, ax=axes[3,0])
sns.boxplot (x='g-7', data=dados, ax=axes[3,1])

# %%
dados['g-3'].hist(bins=100)

# %%
dados['g-11'].hist(bins=100)

# %%
## Desafio 7. Fazer um resumo do que aprendeu com os dados

# %% [markdown]
# Nessa segunda a/ula de imersão, foi possível aprender um pouco mais sobre os dados. Utilizando os recursos do Pandas, Matplotlib e Seaborn, foi possível obter melhor visualização, e explorar as estatísticas básicas de um conjunto de dados.

# %% [markdown]
# # Desafios Aula 3: Correlações, casualidades e relações entre genes

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_cross=pd.crosstab(dados['dose'],dados['tempo'])
dados_cross.head()
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
dados_cross=pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'])
dados_cross.head()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591

# %%
dados_cross=pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='index')
dados_cross.head()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715

# %%
dados_cross=pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='index', values=dados['g-0'], aggfunc='mean')
dados_cross.head()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -2.165955   3.165955
#      48        -0.423801   1.423801
#      72        32.731343 -31.731343
# D2   24         0.085345   0.914655
#      48         0.057868   0.942132

# %%
dados_analis_corr01=dados[['g-0','g-3']]
dados_analis_corr01
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0', y='g-3', data=dados)

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()



# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
## Desafio 1 - Criar tabela de frequencia com o groupby

dados_groupby=dados.groupby(['dose','tempo'])['tratamento'].value_counts()
dados_groupby
# Out:
# dose  tempo  tratamento
# D1    24     com_droga       3585
#              com_controle     301
#       48     com_droga       4011
#              com_controle     343
#       72     com_droga       3600
#              com_controle     307
# D2    24     com_droga       3581
#              com_controle     305
#       48     com_droga       3591
#              com_controle     305
#       72     com_droga       3580
#              com_controle     305
# Name: tratamento, dtype: int64

# %%
## Desafio 2 -  Normalizar o crosstab pela  coluna
dados_cross=pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='columns')

dados_cross.head()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614

# %%
## Desafio 3 - Explorar outros agregadores
dados_cross=pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='index', values=dados['g-0'], aggfunc='std')
dados_cross.head()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.339483   0.660517
#      48         0.335020   0.664980
#      72         0.345301   0.654699
# D2   24         0.444630   0.555370
#      48         0.388810   0.611190

# %%
dados_cross=pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='index', values=dados['g-0'], aggfunc='max')
dados_cross.head()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.245622   0.754378
#      48         0.255010   0.744990
#      72         0.216434   0.783566
# D2   24         0.266278   0.733722
#      48         0.302407   0.697593

# %%
## Desafio 4 - Expplorar o melt

dados_temp=dados
dados_temp
dados_melt=dados_temp.melt(id_vars=['dose','tempo', 'composto'], value_vars=['g-0','g-1','g-3'])
dados_melt
# Out:
#       dose  tempo   composto variable   value
# 0       D1     24  b68db1d53      g-0  1.0620
# 1       D1     72  df89a8e5a      g-0  0.0743
# 2       D1     48  18bb41b2c      g-0  0.6280
# 3       D1     48  8c7f86626      g-0 -0.5138
# 4       D2     72  7cbed3131      g-0 -0.3254
# ...    ...    ...        ...      ...     ...
# 71437   D2     24  df1d0a5a1      g-3 -0.5080
# 71438   D2     24  ecf3b6b74      g-3  0.9905
# 71439   D2     48  cacb2b860      g-3 -0.7389
# 71440   D1     24  8b87a7a83      g-3  0.2044
# 71441   D1     72  972f41291      g-3  0.7952
#
# [71442 rows x 5 columns]

# %%
dados.corr()
# Out:
#           tempo       g-0       g-1  ...      c-97      c-98      c-99
# tempo  1.000000  0.007610  0.043335  ... -0.067969 -0.088916 -0.075736
# g-0    0.007610  1.000000  0.086032  ... -0.622840 -0.640484 -0.609238
# g-1    0.043335  0.086032  1.000000  ... -0.008487 -0.002824 -0.002308
# g-2   -0.162238  0.176188 -0.054518  ... -0.178812 -0.170152 -0.172124
# g-3   -0.031226  0.011266 -0.027855  ... -0.049951 -0.079855 -0.037579
# ...         ...       ...       ...  ...       ...       ...       ...
# c-95  -0.112583 -0.600758 -0.011237  ...  0.811155  0.787529  0.758110
# c-96  -0.067116 -0.646784 -0.022127  ...  0.863061  0.819600  0.789649
# c-97  -0.067969 -0.622840 -0.008487  ...  1.000000  0.801809  0.775300
# c-98  -0.088916 -0.640484 -0.002824  ...  0.801809  1.000000  0.755991
# c-99  -0.075736 -0.609238 -0.002308  ...  0.775300  0.755991  1.000000
#
# [873 rows x 873 columns]

# %%
## Desafio 5 - Calcular e analisar a correlação entre G e C (tipos celulares). Refletir sobre os efeitos biológicos
# c = qtas células sobreviveram ao tratamento = viabilidade celular

#preparo dos dados, cálculo da correlação para um conjunto de genes e celulas

corr_ = dados.loc[:,'g-0':'c-10'].corr()
corr = corr_.loc['g-0':'g-10','c-0':'c-10']

# configuração da exibição com a biblioteca  matplotlib 
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, center=0, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# para aanlisar as relações nos genes e tipos celulares
# para relação entre g e c usando um gráfico de dispersão

dados_temp=dados[['g-6','c-0']]

sns.scatterplot(x='g-6', y='c-0', data=dados)

# %%
# gráfico de dispersão com linha de tendência
sns.lmplot(data=dados, x='g-6', y='c-0',line_kws={'color':'red'})

# %%
# gráfico de dispersão com linha de tendência
sns.lmplot(data=dados, x='g-6', y='c-0',line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
# gráfico de dispersão com linha de tendência
sns.lmplot(data=dados, x='g-1', y='c-0',line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
# gráfico de dispersão com linha de tendência
sns.lmplot(data=dados, x='g-10', y='c-10',line_kws={'color':'red'}, col='tratamento', row='dose')

# %%
## Desafio 6 - Estudar o código que plota a matriz de correlação heatmap()

# %%
# Desafio 7 - Resumo do que aprendeu com os dados.

# %% [markdown]
# Para a aula 3, ´foi possível aprofundar na análise de dados com os recursos da biblioteca Seaborn e Matplotlib que possibilita analisar um conjunto de dados e explorar as diversas funções estatísticas.
#
# Utilizando  o heatmap, scatterplot e lmplot foi possível identificar as correlações mais fracas e mais fortes (-1 a 1) e começar a entender os efeitos nas células dos diversos tratamentos em relação ao tempo, dose.
#
# Foi possível identificar as correlações mais fortes, destacadas pela matriz de cores e o coeficiente de correlação se aproximando de 1.
#
# Um coeficiente de correlação próximo de zero indica que não há relação entre as duas variáveis, e quanto mais eles se aproximam de 1 ou  -1, mais forte é a relação.
#
# Importante observar que uma correlação significativa não necessariamente implica em uma relação de causa e efeito entre as variáveis.

# %% [markdown]
# # Desafios Aula 4: Merge de dados e análise de resultados

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa=dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
#contagem pelas colunas
contagem_moa=dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
#quantidade de mecanismos que foram ativos nmoa 
dados_resultados['nmoa']=dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
#Indica se algum mecanismo foi ativado 

dados_resultados['ativo_moa']=dados_resultados['nmoa']!=0

# %%
# Identifica os elementos (columns) para cada grupo 'inhibitor', 'antagonist', 'agonist', etc. cpmsoderamdp p sufixo col.endswith _sufixo
inibidores = [col for col in dados_resultados if col.endswith('_inhibitor')]
antagonista = [col for col in dados_resultados if col.endswith('_antagonist')]
agonista = [col for col in dados_resultados if col.endswith('_agonist')]
ativador = [col for col in dados_resultados if col.endswith('_activator')]
dados_resultados['nmoa_inibidor']=dados_resultados.loc[:,inibidores].sum(axis=1)
dados_resultados['nmoa_antagonista']=dados_resultados.loc[:,antagonista].sum(axis=1)
dados_resultados['nmoa_agonista']=dados_resultados.loc[:,agonista].sum(axis=1)
dados_resultados['nmoa_ativador']=dados_resultados.loc[:,ativador].sum(axis=1)

# %%
#faz um merge através do id

dados_merge= pd.merge(dados, dados_resultados[['id','nmoa','ativo_moa','nmoa_inibidor','nmoa_antagonista','nmoa_agonista','nmoa_ativador']], on='id')
dados_merge.head()
# Out:
#              id tratamento  ...  nmoa_agonista nmoa_ativador
# 0  id_000644bb2  com_droga  ...              0             0
# 1  id_000779bfc  com_droga  ...              0             0
# 2  id_000a6266a  com_droga  ...              0             0
# 3  id_0015fd391  com_droga  ...              0             0
# 4  id_001626bd3  com_droga  ...              0             0
#
# [5 rows x 883 columns]

# %%
dados_merge.query('tratamento=="com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
# Desafio 01 - Encontrar o top 10 das ações (sufixo inibidor agonista, etc.)
#strings separa a última parte da coluna, inibidor, etc - n maneiras de resolver o problemas.... tem um padrão separando palavras

dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  nmoa_agonista  nmoa_ativador
# 0  id_000644bb2                            0  ...              0              0
# 1  id_000779bfc                            0  ...              0              0
# 2  id_000a6266a                            0  ...              0              0
# 3  id_0015fd391                            0  ...              0              0
# 4  id_001626bd3                            0  ...              0              0
#
# [5 rows x 213 columns]

# %%
# Identifica os elementos (columns) para cada grupo 'inhibitor', 'antagonist', 'agonist', etc. cpmsoderamdp p sufixo col.endswith _sufixo
inibidores = [col for col in dados_resultados if col.endswith('_inhibitor')]
antagonista = [col for col in dados_resultados if col.endswith('_antagonist')]
agonista = [col for col in dados_resultados if col.endswith('_agonist')]
ativador = [col for col in dados_resultados if col.endswith('_activator')]

dados_merge['nmoa_inibidores']=dados_merge.loc[:,inibidores].sum(axis=1)
dados_merge['nmoa_antagonista']=dados_merge.loc[:,antagonista].sum(axis=1)
dados_merge['nmoa_agonista']=dados_merge.loc[:,agonista].sum(axis=1)
dados_merge['nmoa_ativador']=dados_merge.loc[:,ativador].sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-7623a98b9c12> in <module>()
#       5 ativador = [col for col in dados_resultados if col.endswith('_activator')]
#       6
# ----> 7 dados_merge['nmoa_inibidores']=dados_merge.loc[:,inibidores].sum(axis=1)
#       8 dados_merge['nmoa_antagonista']=dados_merge.loc[:,antagonista].sum(axis=1)
#       9 dados_merge['nmoa_agonista']=dados_merge.loc[:,agonista].sum(axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
# ...

# %%
# Identifica os TOP 10  inibidores 
dados_resultados[ [col for col in dados_resultados if col.endswith('_inhibitor')]].sum().sort_values(ascending=False)[:10]

# %%
# Identifica os TOP 10  antagonista 
dados_resultados[antagonista].sum().sort_values(ascending=False)[:10]

# %%
# Identifica os TOP 10  agonista 

dados_resultados[agonista].sum().sort_values(ascending=False)[:10]

# %%
# Identifica os TOP 10  ativador 
dados_resultados[ativador].sum().sort_values(ascending=False)[:10]

# %%
# Desafio 02 - Criar coluna eh_controle 
dados_merge['eh_controle']=dados_merge['tratamento']=="com_controle"
dados_merge

# %%
# Desafio 03 - criar 3 colunas 24, 48, 72
dados_merge['24h']=dados_merge['tempo']==24
dados_merge['48h']=dados_merge['tempo']==48
dados_merge['72h']=dados_merge['tempo']==72
dados_merge.head()

# %%
# Desafio 04 - Estudar sobre combinaçãoa de dataframes - merge

# %% [markdown]
# Podemos usar merge e concat para  a combinação de múltiplas fontes.
#
# Nessa aula utilizamos o merge através de um id único para juntar dois dataframes  'dados_experimentos' e 'dados_resultados'
# ![inner-join.png](data:image/png;base64,...)
#
#
# A função join combina dtaframes a partir de um index ou coluna.
#
# A junção de dois dataframes pode ser feita de múltiplas formas(left, right, e inner)
# merge()
# how = ‘inner’
# Caso queiramos a interseção exata entre as tabelas
#
# how = ‘outer’
# Caso queiramos todas as informações, de ambas tabelas, fazemos um merge “outer”:
#
# how = ‘left’ ou how= ‘right’
# Um merge “left” ou “right” depende de qual tabela vocâ deixa na direita ou esquerda.
#
# O método concat() é útil para juntar múltiplos arquivos
#
# Uma boa dica: (:https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %%
# Desafio 05 - Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)


dados_merge.head()

# %%
# Selecionando o composto
composto_selecionado='18bb41b2c'
# Dados de experimento para o composto
dados_composto_x=dados_merge.query('composto ==@composto_selecionado')
# Informações (estatísticas básicas) sobre o conjunto de dados 
dados_composto_x.describe()

# %%
dados_composto_x.head()

# %%
dados_cross=pd.crosstab([dados_composto_x['dose'],dados['tempo']],dados['tratamento'], values=dados['g-5'], aggfunc='mean')
dados_cross.head()

# %%
# matriz de correlação
corr_dados_x = dados_composto_x.loc[:,'g-0':'g-20'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_dados_x, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_dados_x, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# gráfico 
fig, axes = plt.subplots(1, 2, figsize = (10, 10), sharey = True)
sns.set()
# Analise tempo e dose
sns.boxplot(ax = axes[0], data = dados_composto_x, x = 'composto', y = 'g-6', hue = 'tempo')
sns.boxplot(ax = axes[1], data = dados_composto_x, x = 'composto', y = 'g-6', hue = 'dose')
plt.show()
#sns.lmplot(data=dados_composto_x, x='g-5',  y='g-6', line_kws={'color':'red'}, col='tempo', row='dose')

#sns.boxplot(ax = axes[0], data = composto_selecionado, x = 'composto', y = 'g0', hue = 'tempo')
#sns.boxplot(ax = axes[1], data = composto_analise, x = 'g-1', y = 'g-2', hue = 'dose')
plt.show()

# %%
# Desafio 06 - Descobrir se temos algum composto que dependendo da configuração do experimento ativa algum moa

dados_merge[['composto','nmoa','ativo_moa']].query('ativo_moa==True & nmoa>=1')

# %%
dados_merge['nmoa'].describe()

# %%
# Desafio 07 - Descobrir se temos algum composto que dependendo da configuração do experimento  ativa MOAs diferentes¶

# %%
# Identifica os elementos (columns) para cada grupo 'inhibitor', 'antagonist', 'agonist', etc. cpmsoderamdp p sufixo col.endswith _sufixo
dados_merge[['composto','nmoa','nmoa_inibidor','nmoa_agonista','nmoa_antagonista','nmoa_ativador']].describe()

# %%
# Desafio 7 - Resumo do que aprendeu com os dados.

# %% [markdown]
# Nessa aula foi possível aprofundar um pouco mais nas análises, compreendendo alguns mecanismos de ação e seu efeito nos experimentos e resultados.
#
# Utilizamos a função merge através do id para juntar dois arquivos de dados (os experimentos e os resultados)
#
# Para análise mais detalhadas, exploramos os recursos de criação de novas colunas derivadas de outras.

# %% [markdown]
# # Desafios Aula 5

# %%
# Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_merge.select_dtypes('float64')
y = dados_merge['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %% [markdown]
# Desafio 02: Estude a documentação do Sklearn.
#
# Scikit-learn (sklearn) é a biblioteca mais comumente usada em Python para criar um modelo preditivo em nosso conjunto de dados.
#
# Uma vez que sklearn exige que todas as entradas estejam numéricas, devemos converter todas as variáveis categóricas em numéricas através da codificação das categorias.

# %% [markdown]
# Desafio 03: Pesquisar o fluxograma 'Escolhendo o melhor modelo' choosing the right estimator
# Desafio 04: Teste outras problemas (perguntas). 0, 1 ou +.
# Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever está label.
# Desafio 06: Resumo do que você aprendeu com os dados
